# %% [raw]
# Überschriften
# # H1
# ## H2
# ### H3
#
# Text-Formatierung
# **fett**
# *kursiv*
# ~~durchgestrichen~~
# `inline code`
#
#
#
# Links & Bilder
# [Linktext](https://url.de)
# ![Alttext](bild.png)
#
# Trennlinie
# ---
#
# Blockquote
# > Das ist ein Zitat
#
# Codeblock
# ```python
# df.head()
# ```
